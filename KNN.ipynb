# 152       0      0   0   1   0.555571     1     NaN
# 153       0      0   0   0   1.075206     2     NaN
# 154       0      0   0   0   0.374100     1     NaN
# 155       0      0   0   0   1.172941     2     NaN
# 156       0      0   0   0   0.334794     1     NaN
# 157       0      0   0   0   0.009865     1     NaN
# 158       0      0   0   0   0.816500     1     NaN
# 159       0      0   0   0   0.209376     1     NaN
# 160       0      0   0   0   0.133006     1     NaN
# 161       0      0   0   0   0.167900     1     NaN
# 162       0      0   0   0   8.175318     4     NaN
# 163       0      0   0   0   0.472506     1     NaN
# 164       0      0   0   0   0.078818     1     NaN
# 165       1      0   0   0   1.196235     2     NaN
# 166       1      0   0   0   0.067376     1     NaN
# 167       0      0   0   0   0.133129     1     NaN
# 168       0      0   0   0   2.093441     3     NaN
# 169       0      0   0   0   0.106494     1     NaN
# 170       0      1   0   0   0.167947     1     NaN
# 171       0      0   0   0   0.163200     1     NaN
# 172       0      0   0   0   0.008094     1     NaN
# 173       1      0   0   0   0.750059     1     NaN
# 174       0      0   0   1   1.940112     2     NaN
# 175       0      0   0   1   0.988041     1     NaN
# 176       0      0   0   0   0.115788     1     NaN
# 177       0      0   0   0   0.043953     1     NaN
#
# [178 rows x 25 columns]

# %%
movie_df = pd.read_excel("종합.xlsx")
movie_df
# Out:
#                                         NAME    긍정   중립    부정  개봉 이틀째 관객수  \
# 0                                       극한직업  2871  415   265      700506
# 1                                        말모이  1427  150   180       90958
# 2                                     내안의 그놈  1279  168   117      174098
# 3                          주먹왕 랄프 2: 인터넷 속으로   499  145    49      240237
# 4                                       아쿠아맨  1693  395   253      278019
# 5                                   보헤미안 랩소디  2478  124    36      175949
# 6                                  PMC: 더 벙커  1576  553  1237      349881
# 7                                        글래스   691  227   266      136220
# 8                        극장판 공룡메카드: 타이니소어의 섬   373   90    12       87869
# 9                                        범블비  1150  398   257      527168
# 10                                        뺑반  1503  422   857      376475
# 11                              러브 유어셀프 인 서울   483    3    39      182103
# 12                                      그린 북   252   18     2       23877
# 13                                      스윙키즈  2303  188   362       40755
# 14                                드래곤 길들이기 3   612   80    27      193351
# 15                                        언니   332  123   219       91531
# 16                                       언더독   340   28     9       32537
# 17                     점박이 한반도의 공룡2 : 새로운 낙원   343   74    13      170039
# 18                                   미래의 미라이    90   64   110       27339
# 19                                    구스 베이비    37    8     4       18236
# 20                                 그대 이름은 장미   129   40    45       23799
# 21           극장판 짱구는 못말려: 아뵤! 쿵후 보이즈 ~라면 대란~    32    7     4       10203
# 22                             스파이더맨: 뉴 유니버스   609   80    27       12165
# 23                                       그린치    93   17     3       32286
# 24                      극장판 헬로카봇: 옴파로스 섬의 비밀   398   78    14       77778
# 25                                       마약왕  2531  744  1706      435538
# 26                                알리타: 배틀 엔젤  2906  492   361      546693
# 27                                        증인   951  118   125      167324
# 28                                       사바하  1398  614   648      329503
# 29                               해피 데스데이 2 유   668  138   218      130156
# ..                                       ...   ...  ...   ...         ...
# 148                                     공범자들   531   17    63       20672
# 9         0      0   1   1   7.645694     4  1185.0
# 10        0      0   0   0   8.920429     4  1637.0
# 11        0      0   0   0   1.760041     2   449.0
# 12        0      0   0   0   0.809200     1   246.0
# 13        0      0   0   0   3.090559     3  2299.0
# 14        0      0   0   1   5.765547     3   602.0
# 15        0      0   0   0   1.134953     2   407.0
# 16        0      0   0   0   0.897924     1   357.0
# 17        0      0   0   0   2.688888     3   366.0
# 18        0      0   0   0   0.560641     1   126.0
# 19        0      0   0   0   0.444565     1    43.0
# 20        0      0   0   0   0.491947     1   157.0
# 21        0      0   0   0   1.194271     2    32.0
# 22        0      0   0   0   2.725500     3  2107.0
# 23        0      0   0   0   2.229435     3   100.0
# 24        0      0   0   0   2.684229     3   441.0
# 25        0      0   0   0   9.966941     4  2716.0
# 26        0      0   0   1   8.438735     4  2719.0
# 27        0      0   0   0   6.507206     3   992.0
# 28        0      0   0   0   9.866959     4  1517.0
# 29        0      0   0   0   2.186465     3   595.0
# ..      ...    ...  ..  ..        ...   ...     ...
# 148       0      1   0   0   0.632206     1     NaN
# 149       0      0   1   0   0.783994     1     NaN
# 150       0      0   1   1   2.491147     3     NaN
# 151       1      0   0   0   0.243994     1     NaN
# 152       0      0   0   1   0.555571     1     NaN
# 153       0      0   0   0   1.075206     2     NaN
# 154       0      0   0   0   0.374100     1     NaN
# 155       0      0   0   0   1.172941     2     NaN
# 156       0      0   0   0   0.334794     1     NaN
# 157       0      0   0   0   0.009865     1     NaN
# 158       0      0   0   0   0.816500     1     NaN
# 159       0      0   0   0   0.209376     1     NaN
# 160       0      0   0   0   0.133006     1     NaN
# 161       0      0   0   0   0.167900     1     NaN
# 162       0      0   0   0   8.175318     4     NaN
# 163       0      0   0   0   0.472506     1     NaN
# 164       0      0   0   0   0.078818     1     NaN
# 165       1      0   0   0   1.196235     2     NaN
# 166       1      0   0   0   0.067376     1     NaN
# 167       0      0   0   0   0.133129     1     NaN
# 168       0      0   0   0   2.093441     3     NaN
# 169       0      0   0   0   0.106494     1     NaN
# 170       0      1   0   0   0.167947     1     NaN
# 171       0      0   0   0   0.163200     1     NaN
# 172       0      0   0   0   0.008094     1     NaN
# 173       1      0   0   0   0.750059     1     NaN
# 174       0      0   0   1   1.940112     2     NaN
# 175       0      0   0   1   0.988041     1     NaN
# 176       0      0   0   0   0.115788     1     NaN
# 177       0      0   0   0   0.043953     1     NaN
#
# [178 rows x 25 columns]

# %%
movie_df2 = movie_df

# %%
del movie_df2["NAME"]

# %%
del movie_df2["UBD"]
del movie_df2["흥행등급"]
del movie_df2["긍정댓글"]
del movie_df2["개봉 9일째 관객수"]
del movie_df2["관객증가율"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'UBD'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-a8b7c72e2436> in <module>
# ----> 1 del movie_df2["UBD"]
#       2 del movie_df2["흥행등급"]
#       3 del movie_df2["긍정댓글"]
#       4 del movie_df2["개봉 9일째 관객수"]
#       5 del movie_df2["관객증가율"]
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __delitem__(self, key)
#    3313             # there was no match, this call should raise the appropriate
#    3314             # exception:
# -> 3315             self._data.delete(key)
#    3316
#    3317         # delete from the caches
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in delete(self, item)
#     983         Delete selected item (items if non-unique) in-place.
#     984         """
# --> 985         indexer = self.items.get_loc(item)
#     986
#     987         is_deleted = np.zeros(self.shape[0], dtype=np.bool_)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'UBD'

# %%
X = movie_df2.values

# %%
movie_df3 = pd.read_excel("종합.xlsx")

# %%
y = movie_df3["흥행등급"].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
from sklearn.neighbors import KNeighborsClassifier
clf = KNeighborsClassifier(n_neighbors=5)
clf.fit(X_train, y_train)

print("훈련 세트 정확도: {:.2f}".format(clf.score(X_train, y_train)))
print("테스트 세트 정확도: {:.2f}".format(clf.score(X_test, y_test)))
# Out:
# 훈련 세트 정확도: 0.80
# 테스트 세트 정확도: 0.78

# %%
clf.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')

# %%
print("테스트 세트 예측:", clf.predict(X_test))
# Out:
# 테스트 세트 예측: [2 1 1 1 4 1 3 1 4 3 3 1 3 1 3 1 4 1 1 4 1 1 3 3 4 2 1 3 3 1 4 2 1 2 3 1 1
#  3 1 1 3 3 1 4 1]

# %%
print("테스트 세트 정확도: {:.2f}".format(clf.score(X_test, y_test)))
# Out:
# 테스트 세트 정확도: 0.78

# %%
neighbors_settings = range(1, 11)

training_accuracy = []
test_accuracy = []
for n_neighbors in neighbors_settings:
    # 모델 생성
    clf = KNeighborsClassifier(n_neighbors=n_neighbors)
    clf.fit(X_train, y_train)
    # 훈련 세트 정확도 저장
    training_accuracy.append(clf.score(X_train, y_train))
    # 일반화 정확도 저장
    test_accuracy.append(clf.score(X_test, y_test))
    
plt.plot(neighbors_settings, training_accuracy, label="훈련 정확도")
plt.plot(neighbors_settings, test_accuracy, label="테스트 정확도")
plt.ylabel("정확도")
plt.xlabel("n_neighbors")
plt.legend()
plt.show()

# %%
X2 = movie_df2[["긍정비율","개봉 이틀째 관객수","2일차 스크린수","SF"]].values

# %%
X2_train, X2_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
from sklearn.neighbors import KNeighborsClassifier
clf = KNeighborsClassifier(n_neighbors=5)

# %%
neighbors_settings = range(1, 11)

training_accuracy = []
test_accuracy = []
for n_neighbors in neighbors_settings:
    # 모델 생성
    clf = KNeighborsClassifier(n_neighbors=n_neighbors)
    clf.fit(X2_train, y_train)
    # 훈련 세트 정확도 저장
    training_accuracy.append(clf.score(X2_train, y_train))
    # 일반화 정확도 저장
    test_accuracy.append(clf.score(X2_test, y_test))
    
plt.plot(neighbors_settings, training_accuracy, label="train")
plt.plot(neighbors_settings, test_accuracy, label="test")
plt.ylabel("accuracy")
plt.xlabel("n_neighbors")
plt.legend()
plt.show()

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {
    'n_neighbors' : [3,5,7,9,11],
    'weights' : ['uniform','distance'],
    'metric' : ['euclidean','manhattan']
}

clf = KNeighborsClassifier()
clf_grid = GridSearchCV(estimator=clf,param_grid = param_grid,cv=10)
clf_grid.fit(X_train, y_train)
print(clf_grid.best_params_)
# Out:
# {'metric': 'euclidean', 'n_neighbors': 11, 'weights': 'uniform'}
# C:\Users\CPB06GameN\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)

# %%
clf = KNeighborsClassifier(metric='euclidean', n_neighbors=11, weights='uniform')
clf.fit(X_train, y_train)
print("훈련 세트 정확도: {:.2f}".format(clf.score(X_train, y_train)))
print("테스트 세트 정확도: {:.2f}".format(clf.score(X_test, y_test)))
# Out:
# 훈련 세트 정확도: 0.78
# 테스트 세트 정확도: 0.82
